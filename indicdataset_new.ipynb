# %%
# !pip install datasets
# !pip install torchaudio
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.12.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.19.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.17.0)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torch==2.6.0 in /usr/local/lib/python3.11/dist-packages (from torchaudio) (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (2.8.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.6.0->torchaudio) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch==2.6.0->torchaudio) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.6.0->torchaudio) (3.0.2)

# %%
from datasets import load_dataset
import os
import torchaudio
import torchaudio.transforms as T
import torch

# Load dataset
dataset = load_dataset("DTU54DL/common-accent", split="train")

# Create output directories
os.makedirs("xtts_data/wavs", exist_ok=True)

# Define accents to keep
target_accents = {
    "India and South Asia (India, Pakistan, Sri Lanka)",
}

# Prepare metadata list
metadata = []
resampler = T.Resample(orig_freq=16000, new_freq=16000)

# Loop and filter
max_samples = 500  # Adjust as needed
count = 0

for i, sample in enumerate(dataset):
    accent = sample.get("accent", "")
    if accent not in target_accents:
        continue

    audio_array = sample["audio"]["array"]
    sentence = sample["sentence"]
    filename = f"clip_{count:05d}.wav"
    filepath = f"xtts_data/wavs/{filename}"

    # Save audio
    waveform = torch.tensor(audio_array).unsqueeze(0)
    torchaudio.save(filepath, waveform, 16000)

    metadata.append(f"{filename.replace('.wav', '')}|{sentence}")
    count += 1

    if count >= max_samples:
        break

# Save metadata
with open("xtts_data/metadata.csv", "w", encoding="utf-8") as f:
    f.write("\n".join(metadata))

print(f"✅ Done. Saved {count} samples for fine-tuning.")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ✅ Done. Saved 500 samples for fine-tuning.

# %%
import pandas as pd

# Load correctly with 2 columns
df = pd.read_csv("xtts_data/metadata.csv", sep="|", header=None, names=["filename", "text"])

# Add third column by duplicating 'text'
df["normalized_text"] = df["text"]

# Save the updated metadata with 3 columns
df.to_csv("xtts_data/metadata.csv", sep="|", header=False, index=False)

# Check
df_check = pd.read_csv("xtts_data/metadata.csv", sep="|", header=None)
print(df_check.head())
print(f"Number of columns: {df_check.shape[1]}")
# Out:
#             0                                                  1  \
# 0  clip_00000  Men in orange vests are at work on a construct...
# 1  clip_00001                  This child is getting a pedicure.
# 2  clip_00002                             Did you get the Mayor?
# 3  clip_00003  Finally I didn't have to feel guilty for using...
# 4  clip_00004            I'd still like to have a word with her.
#
#                                                    2
# 0  Men in orange vests are at work on a construct...
# 1                  This child is getting a pedicure.
# 2                             Did you get the Mayor?
# 3  Finally I didn't have to feel guilty for using...
# 4            I'd still like to have a word with her.
# Number of columns: 3

# %%
import os
import random

# Set your data directory and filenames
data_dir = "/content/xtts_data"
input_metadata = os.path.join(data_dir, "metadata.csv")
train_output = os.path.join(data_dir, "metadata_train.csv")
val_output = os.path.join(data_dir, "metadata_val.csv")

# Ratio to split (e.g., 90% train, 10% val)
train_ratio = 0.9

# Read the original metadata
with open(input_metadata, "r", encoding="utf-8") as f:
    lines = f.readlines()

# Shuffle the lines randomly
random.shuffle(lines)

# Split the lines
split_index = int(len(lines) * train_ratio)
train_lines = lines[:split_index]
val_lines = lines[split_index:]

# Write to train and val files
with open(train_output, "w", encoding="utf-8") as f:
    f.writelines(train_lines)

with open(val_output, "w", encoding="utf-8") as f:
    f.writelines(val_lines)

print(f"✅ Split complete!")
print(f"  > Train samples: {len(train_lines)} → {train_output}")
print(f"  > Val samples:   {len(val_lines)} → {val_output}")
# Out:
# ✅ Split complete!
#   > Train samples: 450 → /content/xtts_data/metadata_train.csv
#   > Val samples:   50 → /content/xtts_data/metadata_val.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp -r /content/drive/MyDrive/indicdata ./xtts_data

# %%
# %cd /content
# !git clone -b dev https://github.com/coqui-ai/TTS.git
# %cd TTS
# !pip install -r requirements.txt
# !pip install -e .
# Out:
# /content
# fatal: destination path 'TTS' already exists and is not an empty directory.
# /content/TTS
# Ignoring numpy: markers 'python_version <= "3.10"' don't match your environment
# Ignoring numba: markers 'python_version < "3.9"' don't match your environment
# Requirement already satisfied: numpy>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: cython>=0.29.30 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (3.0.12)
# Requirement already satisfied: scipy>=1.11.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (1.14.1)
# Requirement already satisfied: torch>=2.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (2.6.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (2.6.0+cu124)
# Requirement already satisfied: soundfile>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (0.13.1)
# Requirement already satisfied: librosa>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (0.11.0)
# Requirement already satisfied: scikit-learn>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 10)) (1.6.1)
# Requirement already satisfied: numba>=0.57.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 12)) (0.60.0)
# Requirement already satisfied: inflect>=5.6.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 13)) (7.5.0)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 14)) (4.67.1)
# Requirement already satisfied: anyascii>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 15)) (0.3.2)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 16)) (6.0.2)
# Requirement already satisfied: fsspec>=2023.6.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 17)) (2024.12.0)
# Requirement already satisfied: aiohttp>=3.8.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 18)) (3.11.15)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 19)) (24.2)
# Requirement already satisfied: mutagen==1.47.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 20)) (1.47.0)
# Requirement already satisfied: flask>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 22)) (3.1.0)
# Requirement already satisfied: pysbd>=0.3.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 24)) (0.3.4)
# Requirement already satisfied: umap-learn>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 26)) (0.5.7)
# Requirement already satisfied: pandas<2.0,>=1.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 27)) (1.5.3)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 29)) (3.10.0)
# Requirement already satisfied: trainer>=0.0.36 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 31)) (0.0.36)
# Requirement already satisfied: coqpit>=0.0.16 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 33)) (0.0.17)
# Requirement already satisfied: jieba in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 35)) (0.42.1)
# Requirement already satisfied: pypinyin in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 36)) (0.54.0)
# Requirement already satisfied: hangul_romanize in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 38)) (0.1.0)
# Requirement already satisfied: gruut==2.2.3 in /usr/local/lib/python3.11/dist-packages (from gruut[de,es,fr]==2.2.3->-r requirements.txt (line 40)) (2.2.3)
# Requirement already satisfied: jamo in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 42)) (0.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 43)) (3.9.1)
# Requirement already satisfied: g2pkk>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 44)) (0.1.2)
# Requirement already satisfied: bangla in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 46)) (0.0.2)
# Requirement already satisfied: bnnumerizer in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 47)) (0.0.2)
# Requirement already satisfied: bnunicodenormalizer in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 48)) (0.1.7)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 50)) (0.8.1)
# Requirement already satisfied: transformers>=4.33.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 51)) (4.51.1)
# Requirement already satisfied: encodec>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 53)) (0.1.1)
# Requirement already satisfied: unidecode>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 55)) (1.3.8)
# Requirement already satisfied: num2words in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 56)) (0.5.14)
# Requirement already satisfied: spacy>=3 in /usr/local/lib/python3.11/dist-packages (from spacy[ja]>=3->-r requirements.txt (line 57)) (3.8.5)
# Requirement already satisfied: Babel<3.0.0,>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->-r requirements.txt (line 40)) (2.17.0)
# Requirement already satisfied: dateparser~=1.1.0 in /usr/local/lib/python3.11/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->-r requirements.txt (line 40)) (1.1.8)
# Requirement already satisfied: gruut-ipa<1.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->-r requirements.txt (line 40)) (0.13.0)
# Requirement already satisfied: gruut-lang-en~=2.0.0 in /usr/local/lib/python3.11/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->-r requirements.txt (line 40)) (2.0.1)
# Requirement already satisfied: jsonlines~=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->-r requirements.txt (line 40)) (1.2.0)
# Requirement already satisfied: networkx<3.0.0,>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->-r requirements.txt (line 40)) (2.8.8)
# Requirement already satisfied: python-crfsuite~=0.9.7 in /usr/local/lib/python3.11/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->-r requirements.txt (line 40)) (0.9.11)
# Requirement already satisfied: gruut-lang-de~=2.0.0 in /usr/local/lib/python3.11/dist-packages (from gruut[de,es,fr]==2.2.3->-r requirements.txt (line 40)) (2.0.1)
# Requirement already satisfied: gruut-lang-es~=2.0.0 in /usr/local/lib/python3.11/dist-packages (from gruut[de,es,fr]==2.2.3->-r requirements.txt (line 40)) (2.0.1)
# Requirement already satisfied: gruut-lang-fr~=2.0.0 in /usr/local/lib/python3.11/dist-packages (from gruut[de,es,fr]==2.2.3->-r requirements.txt (line 40)) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->-r requirements.txt (line 6)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->-r requirements.txt (line 6)) (4.13.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->-r requirements.txt (line 6)) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->-r requirements.txt (line 6)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->-r requirements.txt (line 6)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->-r requirements.txt (line 6)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->-r requirements.txt (line 6)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->-r requirements.txt (line 6)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->-r requirements.txt (line 6)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->-r requirements.txt (line 6)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->-r requirements.txt (line 6)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->-r requirements.txt (line 6)) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->-r requirements.txt (line 6)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->-r requirements.txt (line 6)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->-r requirements.txt (line 6)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->-r requirements.txt (line 6)) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->-r requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->-r requirements.txt (line 6)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.1->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.0->-r requirements.txt (line 8)) (1.17.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->-r requirements.txt (line 9)) (3.0.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->-r requirements.txt (line 9)) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->-r requirements.txt (line 9)) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->-r requirements.txt (line 9)) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->-r requirements.txt (line 9)) (0.5.0.post1)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->-r requirements.txt (line 9)) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->-r requirements.txt (line 9)) (1.1.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.3.0->-r requirements.txt (line 10)) (3.6.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.57.0->-r requirements.txt (line 12)) (0.43.0)
# Requirement already satisfied: more_itertools>=8.5.0 in /usr/local/lib/python3.11/dist-packages (from inflect>=5.6.0->-r requirements.txt (line 13)) (10.6.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from inflect>=5.6.0->-r requirements.txt (line 13)) (4.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->-r requirements.txt (line 18)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->-r requirements.txt (line 18)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->-r requirements.txt (line 18)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->-r requirements.txt (line 18)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->-r requirements.txt (line 18)) (6.4.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->-r requirements.txt (line 18)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->-r requirements.txt (line 18)) (1.19.0)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.11/dist-packages (from flask>=2.0.1->-r requirements.txt (line 22)) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from flask>=2.0.1->-r requirements.txt (line 22)) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from flask>=2.0.1->-r requirements.txt (line 22)) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from flask>=2.0.1->-r requirements.txt (line 22)) (1.9.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.1->-r requirements.txt (line 26)) (0.5.13)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.0,>=1.4->-r requirements.txt (line 27)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.0,>=1.4->-r requirements.txt (line 27)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 29)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 29)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 29)) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 29)) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 29)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 29)) (3.2.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from trainer>=0.0.36->-r requirements.txt (line 31)) (5.9.5)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from trainer>=0.0.36->-r requirements.txt (line 31)) (2.18.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->-r requirements.txt (line 43)) (2024.11.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.33.0->-r requirements.txt (line 51)) (0.30.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers>=4.33.0->-r requirements.txt (line 51)) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.33.0->-r requirements.txt (line 51)) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.33.0->-r requirements.txt (line 51)) (0.5.3)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.11/dist-packages (from num2words->-r requirements.txt (line 56)) (0.6.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (0.15.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (2.11.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (75.2.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (3.5.0)
# Requirement already satisfied: sudachipy!=0.6.1,>=0.5.2 in /usr/local/lib/python3.11/dist-packages (from spacy[ja]>=3->-r requirements.txt (line 57)) (0.6.10)
# Requirement already satisfied: sudachidict_core>=20211220 in /usr/local/lib/python3.11/dist-packages (from spacy[ja]>=3->-r requirements.txt (line 57)) (20250129)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.0->-r requirements.txt (line 8)) (2.22)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.11/dist-packages (from dateparser~=1.1.0->gruut==2.2.3->gruut[de,es,fr]==2.2.3->-r requirements.txt (line 40)) (5.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.1->-r requirements.txt (line 6)) (3.0.2)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from jsonlines~=1.2.0->gruut==2.2.3->gruut[de,es,fr]==2.2.3->-r requirements.txt (line 40)) (1.17.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (1.3.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa>=0.10.0->-r requirements.txt (line 9)) (4.3.7)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.33.0->-r requirements.txt (line 51)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.33.0->-r requirements.txt (line 51)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.33.0->-r requirements.txt (line 51)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.33.0->-r requirements.txt (line 51)) (2025.1.31)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (1.2.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (7.1.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard->trainer>=0.0.36->-r requirements.txt (line 31)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard->trainer>=0.0.36->-r requirements.txt (line 31)) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard->trainer>=0.0.36->-r requirements.txt (line 31)) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard->trainer>=0.0.36->-r requirements.txt (line 31)) (5.29.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->trainer>=0.0.36->-r requirements.txt (line 31)) (0.7.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->-r requirements.txt (line 57)) (0.1.2)
# Obtaining file:///content/TTS
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (1.26.4)
# Requirement already satisfied: cython>=0.29.30 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (3.0.12)
# Requirement already satisfied: scipy>=1.11.2 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (1.14.1)
# Requirement already satisfied: torch>=2.1 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (2.6.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (2.6.0+cu124)
# Requirement already satisfied: soundfile>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.13.1)
# Requirement already satisfied: librosa>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.11.0)
# Requirement already satisfied: scikit-learn>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (1.6.1)
# Requirement already satisfied: numba>=0.57.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.60.0)
# Requirement already satisfied: inflect>=5.6.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (7.5.0)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (4.67.1)
# Requirement already satisfied: anyascii>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.3.2)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (6.0.2)
# Requirement already satisfied: fsspec>=2023.6.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (2024.12.0)
# Requirement already satisfied: aiohttp>=3.8.1 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (3.11.15)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (24.2)
# Requirement already satisfied: mutagen==1.47.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (1.47.0)
# Requirement already satisfied: flask>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (3.1.0)
# Requirement already satisfied: pysbd>=0.3.4 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.3.4)
# Requirement already satisfied: umap-learn>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.5.7)
# Requirement already satisfied: pandas<2.0,>=1.4 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (1.5.3)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (3.10.0)
# Requirement already satisfied: trainer>=0.0.36 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.0.36)
# Requirement already satisfied: coqpit>=0.0.16 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.0.17)
# Requirement already satisfied: jieba in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.42.1)
# Requirement already satisfied: pypinyin in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.54.0)
# Requirement already satisfied: hangul_romanize in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.1.0)
# Requirement already satisfied: gruut==2.2.3 in /usr/local/lib/python3.11/dist-packages (from gruut[de,es,fr]==2.2.3->TTS==0.22.0) (2.2.3)
# Requirement already satisfied: jamo in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (3.9.1)
# Requirement already satisfied: g2pkk>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.1.2)
# Requirement already satisfied: bangla in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.0.2)
# Requirement already satisfied: bnnumerizer in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.0.2)
# Requirement already satisfied: bnunicodenormalizer in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.1.7)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.8.1)
# Requirement already satisfied: transformers>=4.33.0 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (4.51.1)
# Requirement already satisfied: encodec>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.1.1)
# Requirement already satisfied: unidecode>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (1.3.8)
# Requirement already satisfied: num2words in /usr/local/lib/python3.11/dist-packages (from TTS==0.22.0) (0.5.14)
# Requirement already satisfied: spacy>=3 in /usr/local/lib/python3.11/dist-packages (from spacy[ja]>=3->TTS==0.22.0) (3.8.5)
# Requirement already satisfied: Babel<3.0.0,>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.22.0) (2.17.0)
# Requirement already satisfied: dateparser~=1.1.0 in /usr/local/lib/python3.11/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.22.0) (1.1.8)
# Requirement already satisfied: gruut-ipa<1.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.22.0) (0.13.0)
# Requirement already satisfied: gruut-lang-en~=2.0.0 in /usr/local/lib/python3.11/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.22.0) (2.0.1)
# Requirement already satisfied: jsonlines~=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.22.0) (1.2.0)
# Requirement already satisfied: networkx<3.0.0,>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.22.0) (2.8.8)
# Requirement already satisfied: python-crfsuite~=0.9.7 in /usr/local/lib/python3.11/dist-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.22.0) (0.9.11)
# Requirement already satisfied: gruut-lang-de~=2.0.0 in /usr/local/lib/python3.11/dist-packages (from gruut[de,es,fr]==2.2.3->TTS==0.22.0) (2.0.1)
# Requirement already satisfied: gruut-lang-es~=2.0.0 in /usr/local/lib/python3.11/dist-packages (from gruut[de,es,fr]==2.2.3->TTS==0.22.0) (2.0.1)
# Requirement already satisfied: gruut-lang-fr~=2.0.0 in /usr/local/lib/python3.11/dist-packages (from gruut[de,es,fr]==2.2.3->TTS==0.22.0) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->TTS==0.22.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->TTS==0.22.0) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->TTS==0.22.0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->TTS==0.22.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->TTS==0.22.0) (6.4.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->TTS==0.22.0) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.8.1->TTS==0.22.0) (1.19.0)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.11/dist-packages (from flask>=2.0.1->TTS==0.22.0) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from flask>=2.0.1->TTS==0.22.0) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from flask>=2.0.1->TTS==0.22.0) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from flask>=2.0.1->TTS==0.22.0) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from flask>=2.0.1->TTS==0.22.0) (1.9.0)
# Requirement already satisfied: more_itertools>=8.5.0 in /usr/local/lib/python3.11/dist-packages (from inflect>=5.6.0->TTS==0.22.0) (10.6.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from inflect>=5.6.0->TTS==0.22.0) (4.4.2)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->TTS==0.22.0) (3.0.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->TTS==0.22.0) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->TTS==0.22.0) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->TTS==0.22.0) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->TTS==0.22.0) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->TTS==0.22.0) (4.13.1)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->TTS==0.22.0) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa>=0.10.0->TTS==0.22.0) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->TTS==0.22.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->TTS==0.22.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->TTS==0.22.0) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->TTS==0.22.0) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->TTS==0.22.0) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->TTS==0.22.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.0->TTS==0.22.0) (2.8.2)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.11/dist-packages (from num2words->TTS==0.22.0) (0.6.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.57.0->TTS==0.22.0) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.0,>=1.4->TTS==0.22.0) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.3.0->TTS==0.22.0) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.0->TTS==0.22.0) (1.17.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (0.15.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (2.11.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (75.2.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy>=3->spacy[ja]>=3->TTS==0.22.0) (3.5.0)
# Requirement already satisfied: sudachipy!=0.6.1,>=0.5.2 in /usr/local/lib/python3.11/dist-packages (from spacy[ja]>=3->TTS==0.22.0) (0.6.10)
# Requirement already satisfied: sudachidict_core>=20211220 in /usr/local/lib/python3.11/dist-packages (from spacy[ja]>=3->TTS==0.22.0) (20250129)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (3.18.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.1->TTS==0.22.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.1->TTS==0.22.0) (1.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from trainer>=0.0.36->TTS==0.22.0) (5.9.5)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from trainer>=0.0.36->TTS==0.22.0) (2.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.33.0->TTS==0.22.0) (0.30.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.33.0->TTS==0.22.0) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.33.0->TTS==0.22.0) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.33.0->TTS==0.22.0) (0.5.3)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn>=0.5.1->TTS==0.22.0) (0.5.13)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.0->TTS==0.22.0) (2.22)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.11/dist-packages (from dateparser~=1.1.0->gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.22.0) (5.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1.2->flask>=2.0.1->TTS==0.22.0) (3.0.2)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from jsonlines~=1.2.0->gruut==2.2.3->gruut[de,es,fr]==2.2.3->TTS==0.22.0) (1.17.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (1.3.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa>=0.10.0->TTS==0.22.0) (4.3.7)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (2025.1.31)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (1.2.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (7.1.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard->trainer>=0.0.36->TTS==0.22.0) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard->trainer>=0.0.36->TTS==0.22.0) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard->trainer>=0.0.36->TTS==0.22.0) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard->trainer>=0.0.36->TTS==0.22.0) (5.29.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->trainer>=0.0.36->TTS==0.22.0) (0.7.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3->spacy[ja]>=3->TTS==0.22.0) (0.1.2)
# Building wheels for collected packages: TTS
#   Building editable for TTS (pyproject.toml) ... done
#   Created wheel for TTS: filename=tts-0.22.0-0.editable-cp311-cp311-linux_x86_64.whl size=15144 sha256=8d1f5637fb3908ec035aa83bbf26ffaab8e887adc280050ba8f8168f2dbf4976
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9am12td5/wheels/a1/31/b6/e4589a2b0e214f7f2ecd464f78aeb7998645a43ff4721bf68b
# Successfully built TTS
# Installing collected packages: TTS
# Successfully installed TTS-0.22.0

# %%
# %cd /content/
# Out:
# /content

# %%
# !pip install transformers==4.30.2
# Out:
# Collecting transformers==4.30.2
#   Downloading transformers-4.30.2-py3-none-any.whl.metadata (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.6/113.6 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.30.2) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.30.2) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.30.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.30.2) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.30.2) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.30.2) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.30.2) (2.32.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.30.2)
#   Downloading tokenizers-0.13.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.30.2) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.30.2) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30.2) (2024.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30.2) (4.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.30.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.30.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.30.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.30.2) (2025.1.31)
# Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 61.7 MB/s eta 0:00:00
# Downloading tokenizers-0.13.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 46.6 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.1
#     Uninstalling tokenizers-0.21.1:
#       Successfully uninstalled tokenizers-0.21.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.51.1
#     Uninstalling transformers-4.51.1:
#       Successfully uninstalled transformers-4.51.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tts 0.22.0 requires transformers>=4.33.0, but you have transformers 4.30.2 which is incompatible.
# sentence-transformers 3.4.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.30.2 which is incompatible.
# Successfully installed tokenizers-0.13.3 transformers-4.30.2

# %%
# !grep -r "LJSpeech" . | grep "/raid"
# Out:
# ./recipes/ljspeech/xtts_v2/train_gpt_xtts.py:    path="/raid/datasets/LJSpeech-1.1_24khz/",
# ./recipes/ljspeech/xtts_v2/train_gpt_xtts.py:    meta_file_train="/raid/datasets/LJSpeech-1.1_24khz/metadata.csv",
# ./recipes/ljspeech/xtts_v1/train_gpt_xtts.py:    path="/raid/datasets/LJSpeech-1.1_24khz/",
# ./recipes/ljspeech/xtts_v1/train_gpt_xtts.py:    meta_file_train="/raid/datasets/LJSpeech-1.1_24khz/metadata.csv",
# grep: ./.git/objects/pack/pack-83ae766851c85d035ae6b6a163c1063c572e1187.pack: binary file matches
# grep: ./tests/inputs/scale_stats.npy: binary file matches

# %%
import pandas as pd

df = pd.read_csv("/content/xtts_data/metadata_val.csv", sep="|", header=None)
print(df.head())
print(f"🔍 Found {len(df)} entries in metadata_val.csv")

# Optional sanity check
import os
missing = [path for path in df[0] if not os.path.exists(os.path.join("/content/xtts_data", path))]
print("❌ Missing files:", missing)
# Out:
#             0                                                  1  \
# 0  clip_00095  He also was the past owner of the Rainfair Com...
# 1  clip_00136       She had no children by any of her marriages.
# 2  clip_00313  The company's mascot is Atomic Betty, who appe...
# 3  clip_00085  The founder of the hospital was William Bromfe...
# 4  clip_00494                His replacement was Billy Campbell.
#
#                                                    2
# 0  He also was the past owner of the Rainfair Com...
# 1       She had no children by any of her marriages.
# 2  The company's mascot is Atomic Betty, who appe...
# 3  The founder of the hospital was William Bromfe...
# 4                His replacement was Billy Campbell.
# 🔍 Found 50 entries in metadata_val.csv
# ❌ Missing files: ['clip_00095', 'clip_00136', 'clip_00313', 'clip_00085', 'clip_00494', 'clip_00404', 'clip_00428', 'clip_00377', 'clip_00191', 'clip_00407', 'clip_00479', 'clip_00374', 'clip_00197', 'clip_00049', 'clip_00333', 'clip_00461', 'clip_00457', 'clip_00438', 'clip_00105', 'clip_00198', 'clip_00411', 'clip_00275', 'clip_00166', 'clip_00088', 'clip_00116', 'clip_00174', 'clip_00074', 'clip_00051', 'clip_00415', 'clip_00169', 'clip_00148', 'clip_00340', 'clip_00158', 'clip_00004', 'clip_00398', 'clip_00325', 'clip_00189', 'clip_00187', 'clip_00059', 'clip_00022', 'clip_00386', 'clip_00238', 'clip_00273', 'clip_00475', 'clip_00250', 'clip_00127', 'clip_00405', 'clip_00037', 'clip_00471', 'clip_00023']

# %%
# !head /content/xtts_data/metadata.csv
# !ls /content/xtts_data/wavs | head
# !ls -lh /content/drive/MyDrive/xtts_finetune/checkpoints
# Out:
# clip_00000|Men in orange vests are at work on a construction site.|Men in orange vests are at work on a construction site.
# clip_00001|This child is getting a pedicure.|This child is getting a pedicure.
# clip_00002|Did you get the Mayor?|Did you get the Mayor?
# clip_00003|Finally I didn't have to feel guilty for using my computer on weekends.|Finally I didn't have to feel guilty for using my computer on weekends.
# clip_00004|I'd still like to have a word with her.|I'd still like to have a word with her.
# clip_00005|This view is wrong though.|This view is wrong though.
# clip_00006|Fedric was unable to find his lucky marble.|Fedric was unable to find his lucky marble.
# clip_00007|Whistle-blower Edward Snowden still lives in exile in Russia.|Whistle-blower Edward Snowden still lives in exile in Russia.
# clip_00008|I work at the hospital as a paediatrician.|I work at the hospital as a paediatrician.
# clip_00009|The squirrel ran up the pine tree in a spiral.|The squirrel ran up the pine tree in a spiral.
# clip_00000.wav
# clip_00001.wav
# clip_00002.wav
# clip_00003.wav
# clip_00004.wav
# clip_00005.wav
# clip_00006.wav
# clip_00007.wav
# clip_00008.wav
# clip_00009.wav
# total 0

# %%
# !rm -rf /content/TTS/recipes/ljspeech/xtts_v2/run/training
# !ln -s /content/drive/MyDrive/xtts_finetune/checkpoints /content/TTS/recipes/ljspeech/xtts_v2/run/training

# %%
# !CUDA_VISIBLE_DEVICES=0 python TTS/recipes/ljspeech/xtts_v2/train_gpt_xtts.py --config_path /content/config.json
# !python TTS/recipes/ljspeech/xtts_v2/train_gpt_xtts.py --config_path /content/config.json --debug > debug_log.txt 2>&1
# !tail -n 50 debug_log.txt
# !python TTS/recipes/ljspeech/xtts_v2/train_gpt_xtts.py --config_path /content/config.json --debug -v
# Out:
#  > Downloading DVAE files!
#   0% 0.00/1.07k [00:00<?, ?iB/s]
# 100% 1.07k/1.07k [00:00<00:00, 5.37kiB/s]
#
#   1% 1.97M/211M [00:00<00:10, 19.7MiB/s]
#   5% 9.50M/211M [00:00<00:03, 52.4MiB/s]
#   8% 17.8M/211M [00:00<00:02, 66.2MiB/s]
#  12% 25.0M/211M [00:00<00:02, 68.5MiB/s]
#  15% 31.8M/211M [00:00<00:02, 65.0MiB/s]
#  18% 38.4M/211M [00:00<00:02, 63.0MiB/s]
#  21% 44.7M/211M [00:00<00:02, 62.3MiB/s]
#  24% 50.9M/211M [00:00<00:02, 58.8MiB/s]
#  27% 57.0M/211M [00:00<00:02, 59.5MiB/s]
#  30% 63.5M/211M [00:01<00:02, 61.1MiB/s]
#  33% 69.9M/211M [00:01<00:02, 61.8MiB/s]
#  36% 76.5M/211M [00:01<00:02, 63.2MiB/s]
#  39% 83.0M/211M [00:01<00:02, 63.5MiB/s]
#  42% 89.3M/211M [00:01<00:01, 62.9MiB/s]
#  45% 95.7M/211M [00:01<00:01, 63.3MiB/s]
#  49% 102M/211M [00:01<00:01, 63.7MiB/s]
#  52% 109M/211M [00:01<00:01, 56.9MiB/s]
#  54% 114M/211M [00:01<00:01, 50.6MiB/s]
#  57% 120M/211M [00:02<00:01, 52.3MiB/s]
#  60% 126M/211M [00:02<00:01, 53.5MiB/s]
#  62% 131M/211M [00:02<00:01, 53.9MiB/s]
#  65% 137M/211M [00:02<00:01, 54.6MiB/s]
#  68% 143M/211M [00:02<00:01, 55.6MiB/s]
#  88% 1.64G/1.87G [00:26<00:04, 54.0MiB/s]
#  88% 1.65G/1.87G [00:26<00:04, 53.1MiB/s]
#  88% 1.65G/1.87G [00:26<00:04, 52.1MiB/s]
#  89% 1.66G/1.87G [00:27<00:03, 56.5MiB/s]
#  89% 1.67G/1.87G [00:27<00:03, 63.4MiB/s]
#  90% 1.68G/1.87G [00:27<00:02, 68.7MiB/s]
#  90% 1.68G/1.87G [00:27<00:02, 71.9MiB/s]
#  91% 1.69G/1.87G [00:27<00:02, 75.7MiB/s]
#  91% 1.70G/1.87G [00:27<00:02, 78.4MiB/s]
#  91% 1.71G/1.87G [00:27<00:02, 78.9MiB/s]
#  92% 1.72G/1.87G [00:27<00:01, 80.6MiB/s]
#  92% 1.73G/1.87G [00:27<00:01, 81.0MiB/s]
#  93% 1.73G/1.87G [00:27<00:01, 82.0MiB/s]
#  93% 1.74G/1.87G [00:28<00:01, 80.4MiB/s]
#  94% 1.75G/1.87G [00:28<00:01, 79.6MiB/s]
#  94% 1.76G/1.87G [00:28<00:01, 72.8MiB/s]
#  95% 1.77G/1.87G [00:28<00:01, 73.0MiB/s]
#  95% 1.77G/1.87G [00:28<00:01, 74.0MiB/s]
#  95% 1.78G/1.87G [00:28<00:01, 74.7MiB/s]
#  96% 1.79G/1.87G [00:28<00:01, 75.6MiB/s]
#  96% 1.80G/1.87G [00:28<00:00, 74.3MiB/s]
#  97% 1.80G/1.87G [00:28<00:00, 74.1MiB/s]
#  97% 1.81G/1.87G [00:28<00:00, 73.8MiB/s]
#  97% 1.82G/1.87G [00:29<00:00, 72.1MiB/s]
#  98% 1.83G/1.87G [00:29<00:00, 72.0MiB/s]
#  98% 1.83G/1.87G [00:29<00:00, 74.2MiB/s]
#  99% 1.84G/1.87G [00:29<00:00, 75.8MiB/s]
#  99% 1.85G/1.87G [00:29<00:00, 76.2MiB/s]
#  99% 1.86G/1.87G [00:29<00:00, 75.7MiB/s]
# 100% 1.86G/1.87G [00:29<00:00, 76.7MiB/s]
# 100% 1.87G/1.87G [00:45<00:00, 76.7MiB/s]>> DVAE weights restored from: /content/TTS/recipes/ljspeech/xtts_v2/run/training/XTTS_v2.0_original_model_files/dvae.pth
#  | > Found 500 files in /content/xtts_data
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
#  > Training Environment:
#  | > Backend: Torch
#  | > Mixed precision: False
#  | > Precision: float32
#  | > Current device: 0
#  | > Num. of GPUs: 1
#  | > Num. of CPUs: 2
#  | > Num. of Torch Threads: 1
#  | > Torch seed: 1
#  | > Torch CUDNN: True
#  | > Torch CUDNN deterministic: False
#  | > Torch CUDNN benchmark: False
#  | > Torch TF32 MatMul: False
# 2025-04-17 10:38:49.812376: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744886329.842146   29710 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744886329.851457   29710 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
#  > Start Tensorboard: tensorboard --logdir=/content/TTS/recipes/ljspeech/xtts_v2/run/training/GPT_XTTS_v2.0_LJSpeech_FT-April-17-2025_10+38AM-0000000
#
#  > Model has 518442047 parameters
#
#  > EPOCH: 0/1000
#  --> /content/TTS/recipes/ljspeech/xtts_v2/run/training/GPT_XTTS_v2.0_LJSpeech_FT-April-17-2025_10+38AM-0000000
#  > Filtering invalid eval samples!!
#  > Total eval samples after filtering: 5
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.06987500190734863 (+0)
#      | > avg_loss_text_ce: 0.022659845650196075 (+0)
#      | > avg_loss_mel_ce: 4.449761390686035 (+0)
#      | > avg_loss: 4.472421169281006 (+0)
#
#
#  > EPOCH: 1/1000
#  --> /content/TTS/recipes/ljspeech/xtts_v2/run/training/GPT_XTTS_v2.0_LJSpeech_FT-April-17-2025_10+38AM-0000000
#  > Sampling by language: dict_keys(['en'])
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
#
#  > TRAINING (2025-04-17 10:39:03)
#
#    --> TIME: 2025-04-17 10:39:09 -- STEP: 0/165 -- GLOBAL_STEP: 0
#      | > loss_text_ce: 0.026062874123454094  (0.026062874123454094)
#      | > loss_mel_ce: 4.1365251541137695  (4.1365251541137695)
#      | > loss: 0.04955461993813515  (0.04955461993813515)
#      | > current_lr: 5e-06
#      | > step_time: 1.3893  (1.3892743587493896)
#      | > loader_time: 4.7697  (4.769678831100464)
#
#
#    --> TIME: 2025-04-17 10:39:45 -- STEP: 50/165 -- GLOBAL_STEP: 50
#      | > loss_text_ce: 0.029011577367782593  (0.02768786735832691)
#      | > loss_mel_ce: 4.420748233795166  (4.0323613834381105)
#      | > loss: 0.05297333374619484  (0.04833392061293125)
#      | > current_lr: 5e-06
#      | > step_time: 0.3938  (0.4784495115280151)
#      | > loader_time: 0.0104  (0.01938545227050781)
#
#
#    --> TIME: 2025-04-17 10:40:24 -- STEP: 100/165 -- GLOBAL_STEP: 100
#      | > loss_text_ce: 0.028849206864833832  (0.02824304547160864)
#      | > loss_mel_ce: 3.7667076587677  (3.9704522037506114)
#      | > loss: 0.04518520087003708  (0.047603515945374965)
#      | > current_lr: 5e-06
#      | > step_time: 0.402  (0.5026343464851378)
#      | > loader_time: 0.0167  (0.017265856266021718)
#
#
#    --> TIME: 2025-04-17 10:41:02 -- STEP: 150/165 -- GLOBAL_STEP: 150
#      | > loss_text_ce: 0.02904125116765499  (0.02808203537017107)
#      | > loss_mel_ce: 3.899068593978882  (3.9714104318618784)
#      | > loss: 0.04676321521401405  (0.04761300660669804)
#      | > current_lr: 5e-06
#      | > step_time: 0.4988  (0.5067716312408443)
#      | > loader_time: 0.008  (0.016143260002136228)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.09529280662536621 (+0.025417804718017578)
#      | > avg_loss_text_ce: 0.02264445088803768 (-1.539476215839386e-05)
#      | > avg_loss_mel_ce: 4.2788286209106445 (-0.17093276977539062)
#      | > avg_loss: 4.301473140716553 (-0.17094802856445312)
#
#  > BEST MODEL : /content/TTS/recipes/ljspeech/xtts_v2/run/training/GPT_XTTS_v2.0_LJSpeech_FT-April-17-2025_10+38AM-0000000/best_model_165.pth
#
#  > EPOCH: 2/1000
#  --> /content/TTS/recipes/ljspeech/xtts_v2/run/training/GPT_XTTS_v2.0_LJSpeech_FT-April-17-2025_10+38AM-0000000
#
#  > TRAINING (2025-04-17 10:43:02)
#
#    --> TIME: 2025-04-17 10:43:37 -- STEP: 35/165 -- GLOBAL_STEP: 200
#      | > loss_text_ce: 0.0287101399153471  (0.02848559000662395)
#      | > loss_mel_ce: 3.5824718475341797  (3.816499294553484)
#      | > loss: 0.04299026355147362  (0.045773630482809885)
#      | > current_lr: 5e-06
#      | > step_time: 0.5333  (0.637481369291033)
#      | > loader_time: 0.0101  (0.03384454590933664)
#
#
#    --> TIME: 2025-04-17 10:44:17 -- STEP: 85/165 -- GLOBAL_STEP: 250
#      | > loss_text_ce: 0.028439940884709358  (0.02838142310433528)
#      | > loss_mel_ce: 3.4924516677856445  (3.8478419808780444)
#      | > loss: 0.04191537946462631  (0.046145517598180225)
#      | > current_lr: 5e-06
#      | > step_time: 0.6868  (0.5902031954597028)
#      | > loader_time: 0.0214  (0.028769560421214386)
#
#
#    --> TIME: 2025-04-17 10:44:57 -- STEP: 135/165 -- GLOBAL_STEP: 300
#      | > loss_text_ce: 0.03236621990799904  (0.02869063868290848)
#      | > loss_mel_ce: 4.0745038986206055  (3.830759701905427)
#      | > loss: 0.04889131337404251  (0.04594583823173136)
#      | > current_lr: 5e-06
#      | > step_time: 0.5261  (0.5685038919802066)
#      | > loader_time: 0.0095  (0.023055334444399233)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.06303834915161133 (-0.03225445747375488)
#      | > avg_loss_text_ce: 0.022639811038970947 (-4.639849066734314e-06)
#      | > avg_loss_mel_ce: 4.108368873596191 (-0.17045974731445312)
#      | > avg_loss: 4.131008625030518 (-0.17046451568603516)
#
#  > BEST MODEL : /content/TTS/recipes/ljspeech/xtts_v2/run/training/GPT_XTTS_v2.0_LJSpeech_FT-April-17-2025_10+38AM-0000000/best_model_330.pth
#
#  > EPOCH: 3/1000
#  --> /content/TTS/recipes/ljspeech/xtts_v2/run/training/GPT_XTTS_v2.0_LJSpeech_FT-April-17-2025_10+38AM-0000000
#
#  > TRAINING (2025-04-17 10:47:06)
#
#    --> TIME: 2025-04-17 10:47:24 -- STEP: 20/165 -- GLOBAL_STEP: 350
#      | > loss_text_ce: 0.027918962761759758  (0.027715277578681707)
#      | > loss_mel_ce: 4.219466209411621  (3.8545533418655396)
#      | > loss: 0.050564106553792953  (0.046217484399676316)
#      | > current_lr: 5e-06
#      | > step_time: 0.417  (0.5175733208656311)
#      | > loader_time: 0.0317  (0.013915312290191651)
#
#
#    --> TIME: 2025-04-17 10:48:03 -- STEP: 70/165 -- GLOBAL_STEP: 400
#      | > loss_text_ce: 0.02961200475692749  (0.0283777885937265)
#      | > loss_mel_ce: 3.7014973163604736  (3.7618905203683037)
#      | > loss: 0.04441796988248825  (0.04512224277215344)
#      | > current_lr: 5e-06
#      | > step_time: 0.5208  (0.5258480344499861)
#      | > loader_time: 0.0101  (0.012816143035888673)
#
#
#    --> TIME: 2025-04-17 10:48:42 -- STEP: 120/165 -- GLOBAL_STEP: 450
#      | > loss_text_ce: 0.03231894597411156  (0.028520988238354524)
#      | > loss_mel_ce: 4.021467208862305  (3.779650115966797)
#      | > loss: 0.04825936257839203  (0.04533537117143471)
#      | > current_lr: 5e-06
#      | > step_time: 0.4052  (0.519423262278239)
#      | > loader_time: 0.0096  (0.013198957840601603)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.09083914756774902 (+0.027800798416137695)
#      | > avg_loss_text_ce: 0.022642765194177628 (+2.954155206680298e-06)
#      | > avg_loss_mel_ce: 3.994699001312256 (-0.11366987228393555)
#      | > avg_loss: 4.017341613769531 (-0.11366701126098633)
#
#  > BEST MODEL : /content/TTS/recipes/ljspeech/xtts_v2/run/training/GPT_XTTS_v2.0_LJSpeech_FT-April-17-2025_10+38AM-0000000/best_model_495.pth
#
#  > EPOCH: 4/1000
#  --> /content/TTS/recipes/ljspeech/xtts_v2/run/training/GPT_XTTS_v2.0_LJSpeech_FT-April-17-2025_10+38AM-0000000
#
#  > TRAINING (2025-04-17 10:51:11)
#
#    --> TIME: 2025-04-17 10:51:18 -- STEP: 5/165 -- GLOBAL_STEP: 500
#      | > loss_text_ce: 0.03149789571762085  (0.029034705832600594)
#      | > loss_mel_ce: 3.685178756713867  (3.967065954208374)
#      | > loss: 0.04424615204334259  (0.04757262691855431)
#      | > current_lr: 5e-06
#      | > step_time: 0.4861  (0.5189686775207519)
#      | > loader_time: 0.0088  (0.009606361389160156)
#
#
#    --> TIME: 2025-04-17 10:51:57 -- STEP: 55/165 -- GLOBAL_STEP: 550
#      | > loss_text_ce: 0.029293401166796684  (0.028146428310058334)
#      | > loss_mel_ce: 4.067643642425537  (3.7811548406427558)
#      | > loss: 0.048773061484098434  (0.04534882510250265)
#      | > current_lr: 5e-06
#      | > step_time: 0.5732  (0.5282865220850164)
#      | > loader_time: 0.01  (0.013769630952314897)
#
#
#    --> TIME: 2025-04-17 10:52:35 -- STEP: 105/165 -- GLOBAL_STEP: 600
#      | > loss_text_ce: 0.02622547559440136  (0.028339348254459246)
#      | > loss_mel_ce: 4.0776896476745605  (3.749873056865874)
#      | > loss: 0.048856135457754135  (0.04497871984328541)
#      | > current_lr: 5e-06
#      | > step_time: 0.5092  (0.5192813646225702)
#      | > loader_time: 0.01  (0.013683702832176571)
#
#
#    --> TIME: 2025-04-17 10:53:13 -- STEP: 155/165 -- GLOBAL_STEP: 650
#      | > loss_text_ce: 0.02297205477952957  (0.0281863690263802)
#      | > loss_mel_ce: 4.1016693115234375  (3.7263008563749254)
#      | > loss: 0.04910287633538246  (0.04469627725981894)
#      | > current_lr: 5e-06
#      | > step_time: 0.3934  (0.5164994070606848)
#      | > loader_time: 0.0097  (0.013019660211378528)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.05854439735412598 (-0.03229475021362305)
#      | > avg_loss_text_ce: 0.022608378902077675 (-3.43862920999527e-05)
#      | > avg_loss_mel_ce: 3.939842700958252 (-0.054856300354003906)
#      | > avg_loss: 3.9624509811401367 (-0.05489063262939453)
#
#  > BEST MODEL : /content/TTS/recipes/ljspeech/xtts_v2/run/training/GPT_XTTS_v2.0_LJSpeech_FT-April-17-2025_10+38AM-0000000/best_model_660.pth
#
#  > EPOCH: 5/1000
#  --> /content/TTS/recipes/ljspeech/xtts_v2/run/training/GPT_XTTS_v2.0_LJSpeech_FT-April-17-2025_10+38AM-0000000
#
#  > TRAINING (2025-04-17 10:55:11)
#
#    --> TIME: 2025-04-17 10:55:46 -- STEP: 40/165 -- GLOBAL_STEP: 700
#      | > loss_text_ce: 0.027798056602478027  (0.02871397980488837)
#      | > loss_mel_ce: 3.7713143825531006  (3.660594344139099)
#      | > loss: 0.0452275276184082  (0.04392033787444234)
#      | > current_lr: 5e-06
#      | > step_time: 0.4325  (0.5437551200389862)
#      | > loader_time: 0.0101  (0.01325278878211975)
#
#
#    --> TIME: 2025-04-17 10:56:24 -- STEP: 90/165 -- GLOBAL_STEP: 750
#      | > loss_text_ce: 0.026594486087560654  (0.028119982903202376)
#      | > loss_mel_ce: 3.694746494293213  (3.7030463192198013)
#      | > loss: 0.044301677495241165  (0.04441864701608818)
#      | > current_lr: 5e-06
#      | > step_time: 0.3339  (0.5206229925155641)
#      | > loader_time: 0.0167  (0.013517435391743977)
#
#
#    --> TIME: 2025-04-17 10:57:05 -- STEP: 140/165 -- GLOBAL_STEP: 800
#      | > loss_text_ce: 0.028889741748571396  (0.028090982631381073)
#      | > loss_mel_ce: 3.5480666160583496  (3.706556837899344)
#      | > loss: 0.042582813650369644  (0.04446009392184871)
#      | > current_lr: 5e-06
#      | > step_time: 0.5538  (0.5378111294337685)
#      | > loader_time: 0.026  (0.0173134412084307)
#
#
#  > EVALUATION
#
#  | > Synthesizing test sentences.
#
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.12033200263977051 (+0.06178760528564453)
#      | > avg_loss_text_ce: 0.022539431229233742 (-6.89476728439331e-05)
#      | > avg_loss_mel_ce: 3.9063873291015625 (-0.03345537185668945)
#      | > avg_loss: 3.928926706314087 (-0.033524274826049805)
#
#  > BEST MODEL : /content/TTS/recipes/ljspeech/xtts_v2/run/training/GPT_XTTS_v2.0_LJSpeech_FT-April-17-2025_10+38AM-0000000/best_model_825.pth
#
#  > EPOCH: 6/1000
#  --> /content/TTS/recipes/ljspeech/xtts_v2/run/training/GPT_XTTS_v2.0_LJSpeech_FT-April-17-2025_10+38AM-0000000
#
#  > TRAINING (2025-04-17 11:00:23)
#
#    --> TIME: 2025-04-17 11:00:51 -- STEP: 25/165 -- GLOBAL_STEP: 850
#      | > loss_text_ce: 0.029285026714205742  (0.029456715136766433)
#      | > loss_mel_ce: 3.53873348236084  (3.6408187675476076)
#      | > loss: 0.042476411908864975  (0.04369375631213188)
#      | > current_lr: 5e-06
#      | > step_time: 0.5873  (0.6894655799865723)
#      | > loader_time: 0.0141  (0.04754830360412598)
